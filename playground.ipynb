# %%
from implementations import compute_normalization_mpmath, compute_normalization_series

# %%
alpha = 1e-6
beta = 1
print(compute_normalization_series(alpha, beta))
print(compute_normalization_mpmath(alpha, beta))
# Out:
# 2.793091002626109e-11
# 2.7930778429668184e-11
